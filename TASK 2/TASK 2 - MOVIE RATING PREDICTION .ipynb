# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split

# %%
data = pd.read_csv('IMDb_Movies_India.csv', encoding="latin1")

data.head()
# Out:
#                                  Name    Year Duration            Genre  \
# 0                                         NaN      NaN            Drama
# 1  #Gadhvi (He thought he was Gandhi)  (2019)  109 min            Drama
# 2                         #Homecoming  (2021)   90 min   Drama, Musical
# 3                             #Yaaram  (2019)  110 min  Comedy, Romance
# 4                   ...And Once Again  (2010)  105 min            Drama
#
#    Rating Votes            Director       Actor 1             Actor 2  \
# 0     NaN   NaN       J.S. Randhawa      Manmauji              Birbal
# 1     7.0     8       Gaurav Bakshi  Rasika Dugal      Vivek Ghamande
# 2     NaN   NaN  Soumyajit Majumdar  Sayani Gupta   Plabita Borthakur
# 3     4.4    35          Ovais Khan       Prateik          Ishita Raj
# 4     NaN   NaN        Amol Palekar  Rajat Kapoor  Rituparna Sengupta
#
#            Actor 3
# 0  Rajendra Bhatia
# 1    Arvind Jangid
# 2       Roy Angana
# 3  Siddhant Kapoor
# 4      Antara Mali

# %%
data.shape
# Out:
# (15509, 10)

# %%
data.tail()
# Out:
#                       Name    Year Duration          Genre  Rating Votes  \
# 15504  Zulm Ko Jala Doonga  (1988)      NaN         Action     4.6    11
# 15505                Zulmi  (1999)  129 min  Action, Drama     4.5   655
# 15506            Zulmi Raj  (2005)      NaN         Action     NaN   NaN
# 15507        Zulmi Shikari  (1988)      NaN         Action     NaN   NaN
# 15508         Zulm-O-Sitam  (1998)  130 min  Action, Drama     6.2    20
#
#             Director           Actor 1         Actor 2        Actor 3
# 15504  Mahendra Shah  Naseeruddin Shah   Sumeet Saigal  Suparna Anand
# 15505     Kuku Kohli      Akshay Kumar  Twinkle Khanna    Aruna Irani
# 15506     Kiran Thej   Sangeeta Tiwari             NaN            NaN
# 15507            NaN               NaN             NaN            NaN
# 15508   K.C. Bokadia        Dharmendra      Jaya Prada    Arjun Sarja

# %%
data.columns
# Out:
# Index(['Name', 'Year', 'Duration', 'Genre', 'Rating', 'Votes', 'Director',
#        'Actor 1', 'Actor 2', 'Actor 3'],
#       dtype='object')

# %%
data.isnull().any()
# Out:
# Name        False
# Year         True
# Duration     True
# Genre        True
# Rating       True
# Votes        True
# Director     True
# Actor 1      True
# Actor 2      True
# Actor 3      True
# dtype: bool

# %%
data['Duration'] = pd.to_numeric(data['Duration'].str.replace(' min', ''), errors='coerce')
data['Duration'].fillna(data['Duration'].mean(), inplace=True)

# %%
data['Year'] = pd.to_numeric(data['Year'].str.strip(' ()'))
data['Year'].fillna(data['Year'].mean(),inplace=True)

# %%
data
# Out:
#                                      Name         Year    Duration  \
# 0                                          1987.012215  128.126519
# 1      #Gadhvi (He thought he was Gandhi)  2019.000000  109.000000
# 2                             #Homecoming  2021.000000   90.000000
# 3                                 #Yaaram  2019.000000  110.000000
# 4                       ...And Once Again  2010.000000  105.000000
# ...                                   ...          ...         ...
# 15504                 Zulm Ko Jala Doonga  1988.000000  128.126519
# 15505                               Zulmi  1999.000000  129.000000
# 15506                           Zulmi Raj  2005.000000  128.126519
# 15507                       Zulmi Shikari  1988.000000  128.126519
# 15508                        Zulm-O-Sitam  1998.000000  130.000000
#
#                  Genre  Rating Votes            Director           Actor 1  \
# 0                Drama     NaN   NaN       J.S. Randhawa          Manmauji
# 1                Drama     7.0     8       Gaurav Bakshi      Rasika Dugal
# 2       Drama, Musical     NaN   NaN  Soumyajit Majumdar      Sayani Gupta
# 3      Comedy, Romance     4.4    35          Ovais Khan           Prateik
# 4                Drama     NaN   NaN        Amol Palekar      Rajat Kapoor
# ...                ...     ...   ...                 ...               ...
# 15504           Action     4.6    11       Mahendra Shah  Naseeruddin Shah
# 15505    Action, Drama     4.5   655          Kuku Kohli      Akshay Kumar
# 15506           Action     NaN   NaN          Kiran Thej   Sangeeta Tiwari
# 15507           Action     NaN   NaN                 NaN               NaN
# 15508    Action, Drama     6.2    20        K.C. Bokadia        Dharmendra
#
#                   Actor 2          Actor 3
# 0                  Birbal  Rajendra Bhatia
# 1          Vivek Ghamande    Arvind Jangid
# 2       Plabita Borthakur       Roy Angana
# 3              Ishita Raj  Siddhant Kapoor
# 4      Rituparna Sengupta      Antara Mali
# ...                   ...              ...
# 15504       Sumeet Saigal    Suparna Anand
# 15505      Twinkle Khanna      Aruna Irani
# 15506                 NaN              NaN
# 15507                 NaN              NaN
# 15508          Jaya Prada      Arjun Sarja
#
# [15509 rows x 10 columns]

# %%
data['Year'] = data['Year'].round(0).astype(int)

# %%
data
# Out:
#                                      Name  Year    Duration            Genre  \
# 0                                          1987  128.126519            Drama
# 1      #Gadhvi (He thought he was Gandhi)  2019  109.000000            Drama
# 2                             #Homecoming  2021   90.000000   Drama, Musical
# 3                                 #Yaaram  2019  110.000000  Comedy, Romance
# 4                       ...And Once Again  2010  105.000000            Drama
# ...                                   ...   ...         ...              ...
# 15504                 Zulm Ko Jala Doonga  1988  128.126519           Action
# 15505                               Zulmi  1999  129.000000    Action, Drama
# 15506                           Zulmi Raj  2005  128.126519           Action
# 15507                       Zulmi Shikari  1988  128.126519           Action
# 15508                        Zulm-O-Sitam  1998  130.000000    Action, Drama
#
#        Rating Votes            Director           Actor 1             Actor 2  \
# 0         NaN   NaN       J.S. Randhawa          Manmauji              Birbal
# 1         7.0     8       Gaurav Bakshi      Rasika Dugal      Vivek Ghamande
# 2         NaN   NaN  Soumyajit Majumdar      Sayani Gupta   Plabita Borthakur
# 3         4.4    35          Ovais Khan           Prateik          Ishita Raj
# 4         NaN   NaN        Amol Palekar      Rajat Kapoor  Rituparna Sengupta
# ...       ...   ...                 ...               ...                 ...
# 15504     4.6    11       Mahendra Shah  Naseeruddin Shah       Sumeet Saigal
# 15505     4.5   655          Kuku Kohli      Akshay Kumar      Twinkle Khanna
# 15506     NaN   NaN          Kiran Thej   Sangeeta Tiwari                 NaN
# 15507     NaN   NaN                 NaN               NaN                 NaN
# 15508     6.2    20        K.C. Bokadia        Dharmendra          Jaya Prada
#
#                Actor 3
# 0      Rajendra Bhatia
# 1        Arvind Jangid
# 2           Roy Angana
# 3      Siddhant Kapoor
# 4          Antara Mali
# ...                ...
# 15504    Suparna Anand
# 15505      Aruna Irani
# 15506              NaN
# 15507              NaN
# 15508      Arjun Sarja
#
# [15509 rows x 10 columns]

# %%
data['Rating'].fillna(data['Rating'].mean(),inplace=True)


data['Votes'] = pd.to_numeric(data['Votes'],errors='coerce')
data['Votes'].fillna(data['Votes'].mean(),inplace=True)
data['Votes'] = data['Votes'].astype(int)
data
# Out:
#                                      Name  Year    Duration            Genre  \
# 0                                          1987  128.126519            Drama
# 1      #Gadhvi (He thought he was Gandhi)  2019  109.000000            Drama
# 2                             #Homecoming  2021   90.000000   Drama, Musical
# 3                                 #Yaaram  2019  110.000000  Comedy, Romance
# 4                       ...And Once Again  2010  105.000000            Drama
# ...                                   ...   ...         ...              ...
# 15504                 Zulm Ko Jala Doonga  1988  128.126519           Action
# 15505                               Zulmi  1999  129.000000    Action, Drama
# 15506                           Zulmi Raj  2005  128.126519           Action
# 15507                       Zulmi Shikari  1988  128.126519           Action
# 15508                        Zulm-O-Sitam  1998  130.000000    Action, Drama
#
#          Rating  Votes            Director           Actor 1  \
# 0      5.841621    120       J.S. Randhawa          Manmauji
# 1      7.000000      8       Gaurav Bakshi      Rasika Dugal
# 2      5.841621    120  Soumyajit Majumdar      Sayani Gupta
# 3      4.400000     35          Ovais Khan           Prateik
# 4      5.841621    120        Amol Palekar      Rajat Kapoor
# ...         ...    ...                 ...               ...
# 15504  4.600000     11       Mahendra Shah  Naseeruddin Shah
# 15505  4.500000    655          Kuku Kohli      Akshay Kumar
# 15506  5.841621    120          Kiran Thej   Sangeeta Tiwari
# 15507  5.841621    120                 NaN               NaN
# 15508  6.200000     20        K.C. Bokadia        Dharmendra
#
#                   Actor 2          Actor 3
# 0                  Birbal  Rajendra Bhatia
# 1          Vivek Ghamande    Arvind Jangid
# 2       Plabita Borthakur       Roy Angana
# 3              Ishita Raj  Siddhant Kapoor
# 4      Rituparna Sengupta      Antara Mali
# ...                   ...              ...
# 15504       Sumeet Saigal    Suparna Anand
# 15505      Twinkle Khanna      Aruna Irani
# 15506                 NaN              NaN
# 15507                 NaN              NaN
# 15508          Jaya Prada      Arjun Sarja
#
# [15509 rows x 10 columns]

# %%
year_count = data['Year'].value_counts().reset_index()
year_count.columns = ['Year','Count']

# %%
plt.rcParams['font.family']='sans-serif'


plt.figure(figsize=(12,6))
plt.bar(data['Year'],data['Duration'])
plt.xlabel('year')
plt.ylabel('Count of duration')
plt.title('average movie duration trend over time')
plt.xticks(rotation=90)
plt.show()

# %%
plt.rcParams['font.family']='sans-serif'


plt.figure(figsize=(12,6))
plt.bar(data['Year'],data['Votes'])
plt.xlabel('year')
plt.ylabel('Count of votes')
plt.title('average movie votes over year')
plt.xticks(rotation=90)
plt.show()

# %%
data.head(3)
# Out:
#                                  Name  Year    Duration           Genre  \
# 0                                      1987  128.126519           Drama
# 1  #Gadhvi (He thought he was Gandhi)  2019  109.000000           Drama
# 2                         #Homecoming  2021   90.000000  Drama, Musical
#
#      Rating  Votes            Director       Actor 1            Actor 2  \
# 0  5.841621    120       J.S. Randhawa      Manmauji             Birbal
# 1  7.000000      8       Gaurav Bakshi  Rasika Dugal     Vivek Ghamande
# 2  5.841621    120  Soumyajit Majumdar  Sayani Gupta  Plabita Borthakur
#
#            Actor 3
# 0  Rajendra Bhatia
# 1    Arvind Jangid
# 2       Roy Angana

# %%
plt.figure(figsize=(8,8))

dframe=data.set_index('Year')

top_movies = dframe[['Name','Rating']].sort_values(by='Rating',ascending=False).head(10)

plots = sns.barplot(x ="Rating",y ="Name", data = top_movies)

for bar in plots.patches:
    plots.annotate(format(bar.get_width(),'.2f'),(bar.get_x() + bar.get_width()+0.3,bar.get_y()+0.5), ha='center')

plt.xlabel("Rating",fontsize=15,fontweight='bold')
plt.ylabel("Name", fontsize=15,fontweight='bold')
plt.title("Top 10 movies based on ratings", fontsize=20,fontweight='bold')

plt.xticks(np.arange(0,13,2),fontweight='bold')
plt.yticks(fontweight='bold')
plt.show()
